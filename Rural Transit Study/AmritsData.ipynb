# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('C:/Users/12035/Desktop/LiftangoData/CompleteDatabase_MLTA.xlsx', skiprows=4, nrows=10000)

# %%
data.columns = data.iloc[0].to_list()
data = data.drop([0])
data.head()
# Out:
#                            Type        Date and Time  Bus Route   Run Trip  \
# 1           104 - Driver change  09/01/2018 00:01:30  101     2  2300    0
# 2            106 - Route change  09/01/2018 00:01:30  101     2  2300    0
# 3              107 - Run change  09/01/2018 00:01:30  101     1  2300    0
# 4  138 - GPS latitude/longitude  09/01/2018 00:02:03  142     1  2350    0
# 5                119 - Got fare  09/01/2018 00:02:03  142     1  2350    0
#
#   Driver Fareset Direction Value Description Amount     Longitude  \
# 1    508       1             508      Driver   0.00  -79.92239380
# 2    508       1               1       Route   0.00  -79.92239380
# 3    508       1            2400         Run   0.00  -79.92239380
# 4    438       1               0    Not Used   0.00  -79.95427704
# 5    438       1              14       Key D   0.00  -79.95427704
#
#       Latitude Stop
# 1  39.61888123    0
# 2  39.61888123    0
# 3  39.61888123    0
# 4  39.63566971    0
# ...

# %%
sorted(data['Route'].unique().astype(int))
# Out:
# [0,
#  1,
#  2,
#  3,
#  6,
#  7,
#  8,
#  11,
#  12,
#  13,
#  14,
#  15,
#  16,
#  29,
#  30,
#  31,
#  38,
#  45,
#  46,
#  47,
#  50,
#  52,
#  70,
#  95,
#  96,
#  100,
#  110,
#  120,
#  130,
#  140,
#  150,
#  160,
#  200,
#  291,
#  292,
#  293,
#  300,
#  301,
#  302,
#  306,
#  307,
#  401,
#  402,
#  403,
#  404,
#  450,
#  460,
#  470,
#  600,
#  800]

# %%
route='7'

# %%
lat = data.loc[data['Route']==route]['Latitude'].astype(float).to_list()
lon = data.loc[data['Route']==route]['Longitude'].astype(float).to_list()
# plt.plot(lat,lon)

plt.figure(figsize=(12,10))
plt.scatter(lon,lat)

# %%
data.loc[(data['Route']==route)][['Type', 'Bus','Latitude','Longitude', 'Date and Time', 'Route']].iloc[280:]
# Out:
#                               Type  Bus     Latitude     Longitude  \
# 5033                119 - Got fare  100  39.64905930  -79.96631622
# 5034                119 - Got fare  100  39.64905930  -79.96631622
# 5081  138 - GPS latitude/longitude  100  39.65485001  -79.96125793
# 5082            129 - Special card  100  39.65485001  -79.96125793
# 5083            129 - Special card  100  39.65485001  -79.96125793
# 5087            106 - Route change  100  39.65485001  -79.96125793
# 5162              107 - Run change  100  39.63164139  -79.95436096
# 5171  138 - GPS latitude/longitude  100  39.63220978  -79.97685242
# 5172                119 - Got fare  100  39.63220978  -79.97685242
# 5298  138 - GPS latitude/longitude  100  39.63500977  -79.95432281
# 5299            129 - Special card  100  39.63500977  -79.95432281
# 5300            129 - Special card  100  39.63500977  -79.95432281
# 5301            129 - Special card  100  39.63500977  -79.95432281
# ...

# %%
len(data.loc[(data['Route']==route) & (data['Type']=='119 - Got fare')])
# Out:
# 106
